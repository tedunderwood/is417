# %% [markdown]
# # Pandas practice, with a glimpse at fuzzy matching

# %%
import csv, os, sys, math, ast, string
from collections import Counter
import pandas as pd
from difflib import SequenceMatcher

# %% [markdown]
# Let's import some optically scanned data; this happens to be derived from the index to the *Book Review Digest,* and has already been extensively processed by Wenyi Shang. I've further focused this list on historical fiction and mysteries, for reasons connected to a project of Madeleine McQuilling's.

# %%
histmyst = pd.read_csv('histandmyst.tsv', sep = '\t')
histmyst.head()
# Out:
#    year               genre                  author                 shorttitle
# 0    21  historical fiction             Buchan, J:            Path of the king
# 1    21  historical fiction        Williams, E. w.         Court of Belshazzar
# 2    21  historical fiction  Kryshanovskaya, V. I.    Torchrbearers of Bohemia
# 3    21  historical fiction         Phillpotts. E.                     Eudocia
# 4    21  historical fiction             Wilson. M.        Forging of the pikes

# %% [markdown]
# As you can see, there are some errors.
#
# Let's try to match this to library metadata. First, however, there's a sneaky problem, which is that there are leading spaces in one column.

# %%
histmyst.iloc[0, 3]
# Out:
# ' Path of the king'

# %%
histmyst['shorttitle'] = histmyst['shorttitle'].str.strip()

# %%
testdf = pd.DataFrame({'shorttitle': ['Path of the king', 'Court of Belshazzar'], 'numcopies': [6, 9]})
testdf.head()
# Out:
#             shorttitle  numcopies
# 0     Path of the king          6
# 1  Court of Belshazzar          9

# %%
merged = testdf.merge(histmyst, left_on = 'shorttitle', right_on = 'shorttitle' how = 'left')
# Out:
# (2, 5)

# %%
hathi = pd.read_csv('hathific1930-49.tsv', sep = '\t')

# %%
merged = histmyst.merge(hathi, on = 'shorttitle', how = 'inner')

# %%
merged.shape
# Out:
# (552, 26)

# %%
hathi.loc[hathi.author == 'Christie, Agatha', :]
# Out:
#                        docid            author  authordate  inferreddate  \
# 381       inu.30000020640763  Christie, Agatha  1890-1976.        1930.0
# 2016      mdp.39015001153629  Christie, Agatha  1890-1976.        1933.0
# 2280        pst.000011280453  Christie, Agatha  1890-1976.        1933.0
# 2510      mdp.39015008016746  Christie, Agatha  1890-1976.        1934.0
# 2511      mdp.39015000682040  Christie, Agatha  1890-1976.        1934.0
# 3715      mdp.39015020689215  Christie, Agatha  1890-1976.        1936.0
# 4097      mdp.39076005032938  Christie, Agatha  1890-1976.        1936.0
# 4301      mdp.39015046448521  Christie, Agatha  1890-1976.        1937.0
# 4302      mdp.39015046391333  Christie, Agatha  1890-1976.        1937.0
# 5150      uc1.32106001973962  Christie, Agatha  1890-1976.        1938.0
# 5314      mdp.39015010390337  Christie, Agatha  1890-1976.        1939.0
# 6480      uc1.32106001973970  Christie, Agatha  1890-1976.        1941.0
# 6481      uc1.32106001974044  Christie, Agatha  1890-1976.        1941.0
# 2510                             NaN  ...   628122         1              1.0
# 2511                             NaN  ...   628125         1              1.0
# 3715                             NaN  ...   628099         1              1.0
# 4097                             NaN  ...  9904778         1              1.0
# 4301                             NaN  ...   628148         1              1.0
# 4302                 Mystery fiction  ...   628153         1              2.0
# 5150                             NaN  ...  7127420         1              1.0
# 5314                             NaN  ...   628157         1              1.0
# 6480                             NaN  ...  7127421         1              1.0
# 6481                             NaN  ...  7127422         1              1.0
# 6766                             NaN  ...  6059508         1              2.0
# 7630   Detective and mystery stories  ...   628115         1              2.0
# 7631                             NaN  ...   628163         2              2.0
# 7827                             NaN  ...  6541706         1              1.0
# 8430                 Mystery fiction  ...  7048167         1              2.0
# 9078                             NaN  ...  7031742         1              1.0
# 9820                             NaN  ...  7490782         1              2.0
# 10047  Detective and mystery stories  ...   663220         1              2.0
# 11618                            NaN  ...  9904777         1              2.0
# 12005                            NaN  ...  4960431         1              2.0
# 12043                            NaN  ...  4960552         1              1.0
# 12046                            NaN  ...  7103244         1              1.0
# 12067                            NaN  ...  3452155         1              1.0
# 12116                            NaN  ...  4960505         1              1.0
# 12117                            NaN  ...  4960558         1              1.0
# 12118                            NaN  ...  4961543         1              1.0
# 12163                            NaN  ...  7586786         1              1.0
# 12207  Detective and mystery stories  ...  7586787         1              1.0
#
#        copiesin25yrs  enumcron  volnum  \
# 381              1.0       NaN     NaN
# 2016             1.0       NaN     NaN
# 2280             1.0       NaN     NaN
# 2510             1.0       NaN     NaN
# 2511             1.0       NaN     NaN
# 3715             1.0       NaN     NaN
# 4097             1.0       NaN     NaN
# 4301             1.0       NaN     NaN
# 4302             1.0       NaN     NaN
# 5150             1.0       NaN     NaN
# 5314             1.0       NaN     NaN
# 6480             1.0       NaN     NaN
# 6481             1.0       NaN     NaN
# 6766             1.0       NaN     NaN
# 7630             1.0       NaN     NaN
# 7631             2.0       NaN     NaN
# 7827             1.0       NaN     NaN
# 8430             1.0       NaN     NaN
# 9078             1.0       NaN     NaN
# 9820             1.0       NaN     NaN
# 10047            1.0       NaN     NaN
# 11618            2.0       NaN     NaN
# 12005            2.0       NaN     NaN
# 12043            1.0       NaN     NaN
# 12046            1.0       NaN     NaN
# 12067            1.0       NaN     NaN
# 12116            1.0       NaN     NaN
# 12117            1.0       NaN     NaN
# 12118            1.0       NaN     NaN
# 12163            1.0       NaN     NaN
# 12207            1.0       NaN     NaN
#
#                                                    title parttitle  \
# 381    The mysterious Mr. Quin / | $c: Aghatha Christie.       NaN
# 2016                                 Thirteen at dinner.       NaN
# 2280          Lord Edgware dies / | $c: Agatha Christie.       NaN
# 2510   Murder in the Calais coach / | $c: Agatha Chri...       NaN
# 2511   Mr. Parker Pyne, detective / | $c: by Agatha C...       NaN
# 3715       The A. B. C. murders; | a new Poirot mystery.       NaN
# 4097                 Surprise endings by Hercule Poirot.       NaN
# 4301   Perilous Journeys of Hercule Poirot : | includ...       NaN
# 4302   Poirot loses a client / | $c: by Agatha Christie.       NaN
# 5150           Appointment with death, a Poirot mystery.       NaN
# 5314   The regatta mystery, and other stories / | $c:...       NaN
# 6480       Evil under the sun, | $c: by Agatha Christie.       NaN
# 6481    The patriotic murders, | $c: by Agatha Christie.       NaN
# 6766   The body in the library, | $c: by Agatha Chris...       NaN
# 7630     Death comes as the end / | $c: Agatha Christie.       NaN
# 7631                                       Towards zero.       NaN
# 7827     Absent in the spring, | $c: by Mary Westmacott.       NaN
# 8430           Remembered death / | $c: Agatha Christie.       NaN
# 9078                 The hollow / | $c: Agatha Christie.       NaN
# 9820   The labors of Hercules / | $c: [by] Agatha Chr...       NaN
# 10047                                   There is a tide.       NaN
# 11618                      Murder on the Orient express.       NaN
# 12005  And then there were none / | $c: Agatha Christie.       NaN
# 12043     Murder in Mesopotamia / | $c: Agatha Christie.       NaN
# 12046  The witness for the prosecution and other stor...       NaN
# 12067  Five complete novels of murder and detection /...       NaN
# 12116         Dead man's mirror / | $c: Agatha Christie.       NaN
# 12117      Murder in three acts / | $c: Agatha Christie.       NaN
# 12118                   N or M? / | $c: Agatha Christie.       NaN
# 12163         Death on the Nile / | $c: Agatha Christie.       NaN
# 12207    Appointment with death / | $c: Agatha Christie.       NaN
#
#        earlyedition                                         shorttitle
# 381            True                            The mysterious Mr. Quin
# 2016           True                                 Thirteen at dinner
# 2280           True                                  Lord Edgware dies
# 2510           True                         Murder in the Calais coach
# 2511           True                         Mr. Parker Pyne, detective
# 3715           True         The A. B. C. murders; a new Poirot mystery
# 4097           True                 Surprise endings by Hercule Poirot
# 4301           True  Perilous Journeys of Hercule Poirot : includin...
# 4302           True                              Poirot loses a client
# 5150           True           Appointment with death, a Poirot mystery
# 5314           True             The regatta mystery, and other stories
# 6480           True                                 Evil under the sun
# 6481           True                              The patriotic murders
# 6766           True                            The body in the library
# 7630           True                             Death comes as the end
# 7631           True                                       Towards zero
# 7827           True                               Absent in the spring
# 8430           True                                   Remembered death
# 9078           True                                         The hollow
# 9820           True                             The labors of Hercules
# 10047          True                                    There is a tide
# 11618         False                       Murder on the Orient express
# 12005         False                           And then there were none
# 12043         False                              Murder in Mesopotamia
# 12046         False  The witness for the prosecution and other stories
# 12067         False       Five complete novels of murder and detection
# 12116         False                                  Dead man's mirror
# 12117         False                               Murder in three acts
# 12118         False                                            N or M?
# 12163         False                                  Death on the Nile
# 12207         False                             Appointment with death
#
# [31 rows x 23 columns]
